# %%
import import_ipynb
from package import *
# Out:
# importing Jupyter notebook from package.ipynb

# %%
X, y = mglearn.datasets.make_forge()
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape:", X.shape)
# Out:
# X.shape: (26, 2)
# /Users/Maxou/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)

# %% [raw]
# Classification k-NN

# %% [raw]
# Dans sa verison la plus simple, k-NN prend en considération qu'un seul plus proche voisin.

# %%
mglearn.plots.plot_knn_classification(n_neighbors=1)
# Out:
# /Users/Maxou/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)

# %% [raw]
# On peut considérer un nombre arbitraire de voisins k. On utilise un "vote" pour affecter un étiquette cad, que pour chaque point du jeu de test, on compte le nombre de voisins qui appartiennent à la classe 0 et de la classe 1. On affecte alors la classe qui est la plus fréquente.

# %%
mglearn.plots.plot_knn_classification(n_neighbors=3)
# Out:
# /Users/Maxou/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)

# %% [raw]
# Comment appliquer le k-NN_classification en utilisant le package scikit-learn ?

# %% [raw]
# Partage nos données en jeu d'apprentissage et jeu de test

# %%
from sklearn.model_selection import train_test_split
X, y = mglearn.datasets.make_forge()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [raw]
# Importer et instancer la classe

# %%
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors=3)

# %% [raw]
# Adapter le classifieur en utilisant le jeu d'apprentissage : enregistrer le jeu de données de manière à pouvoir calculer les voisins au cours de la prédiction

# %%
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [raw]
# Prédire : pour chaque point de donnée du jeu de test, la fonction "predict" calcule ses plus proches voisins dans le jeu d'apprenstisage et trouve ceux-ci la classe la mieux représentée :

# %%
print('Test set predictions: {}'.format(clf.predict(X_test)))
# Out:
# Test set predictions: [1 0 1 0 1 0 0]

# %% [raw]
# Vérification de la généralisation du modèle

# %%
print('Test set accuracy: {:.2f}'.format(clf.score(X_test, y_test)))
# Out:
# Test set accuracy: 0.86

# %% [raw]
# L'exactitude de notre modèle est évaluée à 86%.

# %% [raw]
# On peut aussi visualiser les prédictions dans un plan. Cela permet de voir la frontière de décision, qui est la séparation entre la zone où l'algorithme assigne la valeur de la classe 0 ou la valeur de la classe 1.

# %%
fig, axes = plt.subplots(1, 3, figsize=(10,3))

for n_neighbors, ax in zip([1, 3, 9], axes):
    clf = KNeighborsClassifier(n_neighbors=n_neighbors).fit(X, y)
    mglearn.plots.plot_2d_separator(clf, X, fill=True, eps=0.5, ax=ax, alpha=0.4)
    mglearn.discrete_scatter(X[:,0], X[:,1], y, ax=ax)
    ax.set_title('{} neighbor(s)'.format(n_neighbors))
    ax.set_xlabel('Feature 0')
    ax.set_ylabel('Feature 1')
axes[0].legend(loc=3)

# %% [raw]
# Interprétation :
# Frontière de décision qui suit de près les données d'apprentissage (1 neighbor). Plus il y a de voisins, l-plus la frontière tend à se lisser donc que le modèle devient simple.
# Ainsi, utiliser moins de voisins correspond à une complexité élevée du modèle. Inversement, utiliser plus de voisins correpond à une moindre complexité du modèle.

# %% [raw]
# Confirmation de la relation entre complexité du modèle et généralisation.
#
# Pour cela, on utilise le jeu de données "Cancer"

# %%
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=66)

training_accuracy = []
test_accuracy = []
neighbors_settings = range(1, 11)

for n_neighbors in neighbors_settings:
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X_train, y_train)
    training_accuracy.append(clf.score(X_train, y_train))
    test_accuracy.append(clf.score(X_test, y_test))

plt.plot(neighbors_settings, training_accuracy, label='Training accuracy')
plt.plot(neighbors_settings, test_accuracy, label='Test accuracy')
plt.ylabel('Accuracy')
plt.xlabel('n_neighbors')
plt.legend()

# %% [raw]
# Explication :
#
# La prédiction sur le jeu d'apprentissage est parfaite dans le cas d'un plus proche voisin. Lorsque le nombre de voisins augmente, le modèle devient plus simple et l'exactitude de la prédiction pour les données d'apprentissage chute.
# Le meilleur résultat est obtenu vers le milieu de la courbe, environ pour 6 voisins.
