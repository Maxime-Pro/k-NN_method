# %%
import import_ipynb
from package import *

# %% [raw]
# On utilise le jeu de donnée "wave"

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %% [raw]
# Comment appliquer le k-NN_regression en utilisant le package scikit-learn ?

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

X, y = mglearn.datasets.make_wave(n_samples=40)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

reg = KNeighborsRegressor(n_neighbors=3)
reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print('Test set predictions:\n {}'.format(reg.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-17036e322a9b> in <module>
# ----> 1 print('Test set predictions:\n {:.3f}'.format(reg.predict(X_test)))
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %% [raw]
# On peut aussi évaluer le modèle en utilisant la méthode "score" qui retourne le score R^2 (coefficient de détermination). C'est une mesure de la qualité d'une prédiction pour un modèle de régression.

# %%
print('Test set R^2: {:.2f}'.format(reg.score(X_test, y_test)))
# Out:
# Test set R^2: 0.83

# %% [raw]
# Visualisation des prédictions pour toutes les valeurs possibles pour la caractéristique.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
line = np.linspace(-3, 3, 1000).reshape(-1, 1)
for n_neighbors, ax in zip([1, 3, 9], axes):
    reg = KNeighborsRegressor(n_neighbors = n_neighbors)
    reg.fit(X_train, y_train)
    ax.plot(line, reg.predict(line))
    ax.plot(X_train, y_train, '^', c=mglearn.cm2(0), markersize=8)
    ax.plot(X_test, y_test, 'v', c=mglearn.cm2(1), markersize=8)
    
    ax.set_title("{} neighbor(s) \n train score : {:.2f} | test score: {:.2f}".format(n_neighbors, reg.score(X_train, y_train), reg.score(X_test, y_test)))
    ax.set_xlabel("Feature")
    ax.set_ylabel("Target")

axes[0].legend(["Model predictions", "Training data/target", "Test data/target"], loc="best")

# %% [raw]
# FORCES, FAIBLESSES, et PARAMÈTRES
#
# Le classifieur KNeighbors possède 2 paramètres : nombre de voisins et méthode de mesure de la distance entre les points de données.
# En règle général, choisir un n_neighbors entre 3 et 5 donne souvent de bons résultats de prédiction.
# De plus, par défaut, on utilise la distance euclidienne qui donne aussi en général de bons résultats.
#
# FORCES :
#
#     - Facile à comprendre
#     - Performances raisonnables avec de faibles réajustements
#     - Rapide à construire
#
# FAIBLESSES :
#
#     - Calcul de la prédiction peut être lent si jeu de donnée étendu
#     - Nécessite d'effectuer un prétraitement des données
#     - Mauvais pour les jeux de données dont la plupart des caractéristiques sont nulles (sparse datasets)
#
# Il n'est donc pas souvent utiliser en pratique, du fait de sa lenteur et de son incapacité à gérer de nombreuses caractéristiques.
